# %% [markdown]
# ### Import Essential Libraries

# %%
# import libraries
import pandas as pd
import re

# %% [markdown]
# ### Load Dataframes

# %% [markdown]
# #### Song Names Dataframe

# %%
# create a dataframe from "names.csv" - holds names of the songs
song_names = pd.read_csv('names.csv')

# %%
# check the work
song_names
# Out:
#                                      names
# 0                                 LayLaLay
# 1     Dù Cho Mai Về Sau (Acoustic Version)
# 2                        Xin Đừng Nhấc Máy
# 3                      Có Lẽ Anh Chưa Từng
# 4                              Cho Mình Em
# ...                                    ...
# 2238                                iceman
# 2239                                   Thở
# 2240                     Nhớ Người Hay Nhớ
# 2241                           Như Ngày Đó
# 2242                             KHONG SAO
#
# [2243 rows x 1 columns]

# %% [markdown]
# #### Song Artists Dataframe

# %%
# create a dataframe from "artists.csv" - holds artists of the songs
song_artists = pd.read_csv('artists.csv')

# %%
# check the work
song_artists
# Out:
#             artists
# 0        Jack - J97
# 1     buitruonglinh
# 2             B Ray
# 3            Only C
# 4              Binz
# ...             ...
# 2238           Sol7
# 2239         Da LAB
# 2240           Khói
# 2241           Khói
# 2242          Tommy
#
# [2243 rows x 1 columns]

# %% [markdown]
# #### Song Lyrics Dataframe

# %%
# create a dataframe from "lyrics.csv" - holds lyrics of the songs
song_lyrics = pd.read_csv('lyrics.csv')

# %%
# check the work
song_lyrics
# Out:
#                                                  lyrics
# 0                                                  None
# 1                                                  None
# 2      Anh biết em nói là không muốn gặp anh nữa. An...
# 3                                                  None
# 4      Binz:. Anh từng xem một người là thế giới, an...
# ...                                                 ...
# 2238   [Sol7]Rolling some tree và mọi thứ dần chậm đ...
# 2239                                               None
# 2240   [Sofia]:. Nhớ người, hay nhớ ta!?. Nhớ, người...
# 2241                                               None
# 2242   Lil Tommy not an oven but I been stay with th...
#
# [2243 rows x 1 columns]

# %% [markdown]
# #### Song Genres Dataframe

# %%
# create a dataframe from "genres.txt" - holds genres of the songs
song_genres = pd.read_csv('genres.csv')

# %%
# remove strange characters in the song names 
chars_to_remove = ['[', ']', "'", '"', "."]
regular_expression = '[' + re.escape (''. join (chars_to_remove)) + ']'
song_genres['genres'] = song_genres['genres'].str.replace(regular_expression, ' ', regex=True)
song_genres['genres'] = song_genres['genres'].str.strip()
song_genres['genres'] = song_genres['genres'].str.replace(' ', '')

# %%
# recode observations
original = ['v-pop', 'indieviet,v-pop,vietnamesehiphop', 'v-pop,vietnamesehiphop', 'v-pop,vietnamesesinger-songwriter', \
            'indieviet,v-pop', 'indieviet,rockviet,v-pop,vietnamesesinger-songwriter', 'indieviet,rockviet,v-pop', \
            'vietnamesehiphop', 'rockviet,v-pop', 'v-pop,vietnamesepop', 'indieviet', 'indieviet,v-pop,vietnamesesinger-songwriter', \
            'v-pop,vietnamesebolero', 'v-pop,vietnamesehiphop,vietnamesesinger-songwriter', 'vietlo-fi', '', \
            'v-pop,vietnamesebolero,vietnamesepop', 'vietnamesebolero,vietnamesepop', 'vietnamesebolero', 'v-pop,vietlo-fi', \
            'vinahouse', 'vietnamesesinger-songwriter', 'k-pop', 'vietnamesepop', 'indieviet,vietnamesehiphop', \
            'alternativer&b,dancepop,pop,r&b', 'bemani', 'canadiancontemporaryr&b,pop,r&b', \
            'edm,popdance,tropicalhouse', 'vietinstrumental', 'viralpop', 'somatiktechno,vietnamesehiphop', \
            'chillr&b', 'greekhiphop,greekpop', 'indieviet,vietedm', 'progressivepost-hardcore']

recoded = ['Pop/Ballad', 'Indie/Hip Hop', 'Indie/Hip Hop', 'Pop/Ballad', \
           'Indie/Hip Hop', 'Indie/Hip Hop', 'Indie/Hip Hop', \
           'Indie/Hip Hop', 'Indie/Hip Hop', 'Pop/Ballad', 'Indie/Hip Hop', 'Indie/Hip Hop', \
           'Other', 'Indie/Hip Hop', 'Pop/Ballad', 'Other', \
           'Other', 'Other', 'Other', 'Pop/Ballad', \
           'Other', 'Pop/Ballad', 'Other', 'Pop/Ballad', 'Indie/Hip Hop', \
           'Other', 'Other', 'Other', \
           'Other', 'Other', 'Other', 'Indie/Hip Hop', \
           'Indie/Hip Hop', 'Indie/Hip Hop', 'Indie/Hip Hop', 'Other']

song_genres['genres'] = song_genres['genres'].replace(original, recoded)

# %%
# check the work
song_genres
# Out:
#              genres
# 0        Pop/Ballad
# 1     Indie/Hip Hop
# 2     Indie/Hip Hop
# 3        Pop/Ballad
# 4     Indie/Hip Hop
# ...             ...
# 2238  Indie/Hip Hop
# 2239  Indie/Hip Hop
# 2240  Indie/Hip Hop
# 2241  Indie/Hip Hop
# 2242          Other
#
# [2243 rows x 1 columns]

# %% [markdown]
# #### Song Features Dataframe

# %%
# read "features.csv" - holds features of the songs
song_features = pd.read_csv('features.csv')
song_features = song_features.reset_index() 
song_features = song_features.drop(columns=['index', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'time_signature'])

# %%
# check the work
song_features
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.549   0.568    6    -8.159     0       0.1760        0.0859
# 1            0.640   0.355   11    -7.637     1       0.0876        0.8000
# 2            0.873   0.755    7    -4.506     1       0.1400        0.2930
# 3            0.635   0.439    9   -10.434     0       0.0444        0.6090
# 4            0.603   0.412    0   -10.359     1       0.0579        0.8910
# ...            ...     ...  ...       ...   ...          ...           ...
# 2238         0.919   0.459   10    -9.739     0       0.2020        0.4880
# 2239         0.576   0.750    7    -5.577     1       0.0525        0.5560
# 2240         0.587   0.608   11    -6.956     1       0.0778        0.7040
# 2241         0.688   0.573    0   -11.372     0       0.4680        0.3510
# 2242         0.723   0.667    0    -9.191     1       0.0735        0.7410
#
#       instrumentalness  liveness  valence    tempo  duration_ms
# 0             0.000000    0.0863    0.351  174.038       231724
# 1             0.000000    0.1100    0.815  145.142       213490
# 2             0.000000    0.0881    0.773   94.017       187454
# 3             0.000000    0.2000    0.661  147.871       294535
# 4             0.021200    0.1150    0.371   99.886       206400
# ...                ...       ...      ...      ...          ...
# 2238          0.000015    0.0609    0.869  142.970       178142
# 2239          0.000000    0.0994    0.421  160.079       228050
# 2240          0.000012    0.3460    0.188  159.819       254035
# 2241          0.000000    0.0993    0.567  159.955       263706
# 2242          0.030800    0.1900    0.290   82.003       216223
#
# [2243 rows x 12 columns]

# %% [markdown]
# ### Merge Dataframes

# %%
# merge above dataframes
df = pd.merge(song_names, song_artists, how='inner', left_index=True, right_index=True)
df = df.join(song_lyrics)
df = df.join(song_genres)
df = df.join(song_features)

# %%
df
# Out:
#                                      names        artists  \
# 0                                 LayLaLay     Jack - J97
# 1     Dù Cho Mai Về Sau (Acoustic Version)  buitruonglinh
# 2                        Xin Đừng Nhấc Máy          B Ray
# 3                      Có Lẽ Anh Chưa Từng         Only C
# 4                              Cho Mình Em           Binz
# ...                                    ...            ...
# 2238                                iceman           Sol7
# 2239                                   Thở         Da LAB
# 2240                     Nhớ Người Hay Nhớ           Khói
# 2241                           Như Ngày Đó           Khói
# 2242                             KHONG SAO          Tommy
#
#                                                  lyrics         genres  \
# 0                                                  None     Pop/Ballad
# 1                                                  None  Indie/Hip Hop
# 2      Anh biết em nói là không muốn gặp anh nữa. An...  Indie/Hip Hop
# 3                                                  None     Pop/Ballad
# 4      Binz:. Anh từng xem một người là thế giới, an...  Indie/Hip Hop
# ...                                                 ...            ...
# 2238   [Sol7]Rolling some tree và mọi thứ dần chậm đ...  Indie/Hip Hop
# 2239                                               None  Indie/Hip Hop
# 2240   [Sofia]:. Nhớ người, hay nhớ ta!?. Nhớ, người...  Indie/Hip Hop
# 2241                                               None  Indie/Hip Hop
# 2242   Lil Tommy not an oven but I been stay with th...          Other
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.549   0.568    6    -8.159     0       0.1760        0.0859
# 1            0.640   0.355   11    -7.637     1       0.0876        0.8000
# 2            0.873   0.755    7    -4.506     1       0.1400        0.2930
# 3            0.635   0.439    9   -10.434     0       0.0444        0.6090
# 4            0.603   0.412    0   -10.359     1       0.0579        0.8910
# ...            ...     ...  ...       ...   ...          ...           ...
# 2238         0.919   0.459   10    -9.739     0       0.2020        0.4880
# 2239         0.576   0.750    7    -5.577     1       0.0525        0.5560
# 2240         0.587   0.608   11    -6.956     1       0.0778        0.7040
# 2241         0.688   0.573    0   -11.372     0       0.4680        0.3510
# 2242         0.723   0.667    0    -9.191     1       0.0735        0.7410
#
#       instrumentalness  liveness  valence    tempo  duration_ms
# 0             0.000000    0.0863    0.351  174.038       231724
# 1             0.000000    0.1100    0.815  145.142       213490
# 2             0.000000    0.0881    0.773   94.017       187454
# 3             0.000000    0.2000    0.661  147.871       294535
# 4             0.021200    0.1150    0.371   99.886       206400
# ...                ...       ...      ...      ...          ...
# 2238          0.000015    0.0609    0.869  142.970       178142
# 2239          0.000000    0.0994    0.421  160.079       228050
# 2240          0.000012    0.3460    0.188  159.819       254035
# 2241          0.000000    0.0993    0.567  159.955       263706
# 2242          0.030800    0.1900    0.290   82.003       216223
#
# [2243 rows x 16 columns]

# %%
# remove rows 
df['names'] = df['names'].drop_duplicates()
df = df.drop(df[df.genres == 'Other'].index)
df= df.dropna()
df = df.reset_index(drop=True)

# %% [markdown]
# #### Data Codebook:
# * names: Name of the song.
# * artists: Artist(s) of the song.
# * lyrics: Lyrics of the song.
# * genres: Genre of the song.
# * danceability: Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
# * energy: Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy.
# * key: Key is the major or minor scale around which a piece of music revolves.
# * loudness: The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track. Values typical range between -60 and 0 db.
# * mode: Mode indicates the modality (major or minor) of a track, the type of scale from which its melodic content is derived.
# * speechiness: Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value.
# * acousticness: A measure from 0.0 to 1.0 of whether the track is acoustic.
# * instrumentalness: Predicts whether a track contains no vocals. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content.
# * liveness: Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live.
# * valence: A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
# * tempo: The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
# * duration_ms: Duration of the song in millisecond.

# %%
# check the work
df = df.drop(columns=['artists', 'lyrics'])
df
# Out:
#                                      names         genres  danceability  \
# 0                                 LayLaLay     Pop/Ballad         0.549
# 1     Dù Cho Mai Về Sau (Acoustic Version)  Indie/Hip Hop         0.640
# 2                        Xin Đừng Nhấc Máy  Indie/Hip Hop         0.873
# 3                      Có Lẽ Anh Chưa Từng     Pop/Ballad         0.635
# 4                              Cho Mình Em  Indie/Hip Hop         0.603
# ...                                    ...            ...           ...
# 1215                     Chỉ Một Ngày Thôi  Indie/Hip Hop         0.579
# 1216        Ngày Lang Thang - Solo Version  Indie/Hip Hop         0.674
# 1217                             Self Love  Indie/Hip Hop         0.908
# 1218                                iceman  Indie/Hip Hop         0.919
# 1219                                   Thở  Indie/Hip Hop         0.576
#
#       energy  key  loudness  mode  speechiness  acousticness  \
# 0      0.568    6    -8.159     0       0.1760        0.0859
# 1      0.355   11    -7.637     1       0.0876        0.8000
# 2      0.755    7    -4.506     1       0.1400        0.2930
# 3      0.439    9   -10.434     0       0.0444        0.6090
# 4      0.412    0   -10.359     1       0.0579        0.8910
# ...      ...  ...       ...   ...          ...           ...
# 1215   0.646    3    -8.551     1       0.1480        0.8640
# 1216   0.753    0    -7.123     1       0.1800        0.5340
# 1217   0.344    7   -14.412     0       0.3470        0.6530
# 1218   0.459   10    -9.739     0       0.2020        0.4880
# 1219   0.750    7    -5.577     1       0.0525        0.5560
#
#       instrumentalness  liveness  valence    tempo  duration_ms
# 0             0.000000    0.0863   0.3510  174.038       231724
# 1             0.000000    0.1100   0.8150  145.142       213490
# 2             0.000000    0.0881   0.7730   94.017       187454
# 3             0.000000    0.2000   0.6610  147.871       294535
# 4             0.021200    0.1150   0.3710   99.886       206400
# ...                ...       ...      ...      ...          ...
# 1215          0.000000    0.4320   0.5560  150.006       155100
# 1216          0.000000    0.1250   0.7020   89.895       240000
# 1217          0.000901    0.1060   0.0944  129.924       183444
# 1218          0.000015    0.0609   0.8690  142.970       178142
# 1219          0.000000    0.0994   0.4210  160.079       228050
#
# [1220 rows x 14 columns]

# %%
# number of rows for 'Pop/Ballad'
print(df[df.genres == 'Pop/Ballad'].shape[0])

# number of rows for 'Hip Hop'
print(df[df.genres == 'Indie/Hip Hop'].shape[0])
# Out:
# 656
# 564

# %%
# write to csv file
df.to_csv('vpop.csv', index=False)
